# %%
import pandas as pd

df = pd.read_csv('/Users/robertbuckley/repos/DS-Unit-2-Applied-Modeling/module2-wrangle-ml-datasets/PGA_Data_Historical.csv')

# %%
df.head()
# Out:
#        Player Name  Season         Statistic                     Variable  \
# 0  Robert Garrigus    2010  Driving Distance  Driving Distance - (ROUNDS)
# 1     Bubba Watson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 2   Dustin Johnson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 3  Brett Wetterich    2010  Driving Distance  Driving Distance - (ROUNDS)
# 4      J.B. Holmes    2010  Driving Distance  Driving Distance - (ROUNDS)
#
#   Value
# 0    71
# 1    77
# 2    83
# 3    54
# 4   100

# %%
stat_list = df[df['Season'] == 2010].Statistic.unique().tolist()

# %%
stat_list
# Out:
# ['Driving Distance',
#  'Driving Accuracy Percentage',
#  'Greens in Regulation Percentage',
#  'Putting Average',
#  'Par Breakers',
#  'Total Eagles',
#  'Total Birdies',
#  'Scoring Average (Actual)',
#  'Money Leaders',
#  'Sand Save Percentage',
#  'Par 3 Birdie or Better Leaders',
#  'Par 4 Birdie or Better Leaders',
#  'Par 5 Birdie or Better Leaders',
#  'Birdie or Better Conversion Percentage',
#  'Putts Per Round',
#  'Scoring Average',
#  'All-Around Ranking',
#  'Total Driving',
#  'Scrambling',
#  'Ryder Cup Points',
#  'PGA Championship Points',
#  'Putts made Distance',
#  'Top 10 Finishes',
#  'Non-member Earnings',
#  'Par 3 Scoring Average',
#  'Par 4 Scoring Average',
#  'Par 5 Scoring Average',
#  "3-Putt Avoidance - 15-20'",
#  "3-Putt Avoidance - 20-25'",
#  "3-Putt Avoidance > 25'",
#  'Current Par or Better Streak',
#  "Rounds in the 60's",
#  'Money per Event Leaders',
#  'Eagles (Holes per)',
#  'Birdie Average',
#  'World Money List',
#  'Ball Striking',
#  'Longest Drives',
#  'Bounce Back',
#  'Par 3 Performance',
#  'Par 4 Performance',
#  'Par 5 Performance',
#  'World Golf Ranking Points',
#  'Official World Golf Ranking',
#  'Presidents Cup (International)',
#  'Money Ldrs /w/WGC Non-Mbr Money',
#  'GIR Percentage from Fairway',
#  'Total Money (Official and Unofficial)',
#  'GIR Percentage from Other than Fairway',
#  'Front 9 Scoring Average',
#  'Back 9 Scoring Average',
#  'First Tee Early Scoring Average',
#  'Tenth Tee Early Scoring Average',
#  'First Tee Late Scoring Average',
#  'Tenth Tee Late Scoring Average',
#  'Hit Fairway Percentage',
#  'Driving Pct. 300+ (All Drives)',
#  'Driving Pct. 280-300 (All Drives)',
#  'Driving Pct. 260-280 (All Drives)',
#  'Driving Pct. 240-260 (All Drives)',
#  'Driving Pct. <= 240 (All Drives)',
#  'Final Round Performance',
#  'Top 10 Final Round Performance',
#  'Front 9 Par 3 Scoring Average',
#  'Back 9 Par 3 Scoring Average',
#  'Early Par 3 Scoring Average',
#  'Late Par 3 Scoring Average',
#  'First Tee Early Par 3 Scoring Average',
#  'Tenth Tee Early Par 3 Scoring Average',
#  'First Tee Late Par 3 Scoring Average',
#  'Tenth Tee Late Par 3 Scoring Average',
#  'Front 9 Par 4 Scoring Average',
#  'Back 9 Par 4 Scoring Average',
#  'Early Par 4 Scoring Average',
#  'Late Par 4 Scoring Average',
#  'First Tee Early Par 4 Scoring Average',
#  'Tenth Tee Early Par 4 Scoring Average',
#  'First Tee Late Par 4 Scoring Average',
#  'Tenth Tee Late Par 4 Scoring Average',
#  'Front 9 Par 5 Scoring Average',
#  'Back 9 Par 5 Scoring Average',
#  'Early Par 5 Scoring Average',
#  'Late Par 5 Scoring Average',
#  'First Tee Early Par 5 Scoring Average',
#  'Tenth Tee Early Par 5 Scoring Average',
#  'First Tee Late Par 5 Scoring Average',
#  'Tenth Tee Late Par 5 Scoring Average',
#  'Early Scoring Average',
#  'Late Scoring Average',
#  'Best YTD Streak w/o a 3-Putt',
#  'Best YTD 1-Putt or Better Streak',
#  'Consecutive Sand Saves',
#  'Consecutive Fairways Hit',
#  'Consecutive GIR',
#  'Lowest Round',
#  'Victory Leaders',
#  'Back 9 Lowest Round',
#  'First Tee Early Lowest Round',
#  'Tenth Tee Early Lowest Round',
#  'First Tee Late Lowest Round',
#  'Tenth Tee Late Lowest Round',
#  'Top 5 Final Round Performance',
#  '11-25 Final Round Performance',
#  '25+ Final Round Performance',
#  'Driving Distance - All Drives',
#  'GIR Percentage - 200+ yards',
#  'GIR Percentage - 175-200 yards',
#  'GIR Percentage - 150-175 yards',
#  'GIR Percentage - 125-150 yards',
#  'GIR Percentage - < 125 yards',
#  'Proximity to Hole',
#  'Approaches from > 200 yards',
#  'Approaches from 175-200 yards',
#  'Approaches from 150-175 yards',
#  'Approaches from 125-150 yards',
#  'Approaches from 50-125 yards',
#  "Putting from 3'",
#  "Putting from 4'",
#  "Putting from 5'",
#  "Putting from 6'",
#  "Putting from 7'",
#  "Putting from 8'",
#  "Putting from 9'",
#  "Putting from 10'",
#  'Approach Putt Performance',
#  'Total Hole Outs',
#  'Longest Hole Outs (in yards)',
#  'Birdie or Better Percentage',
#  "Putting from - > 10'",
#  'Birdie or Better Percentage - 200+ yards',
#  'Birdie or Better Percentage - 175-200 yards',
#  'Birdie or Better Percentage - 150-175 yards',
#  'Birdie or Better Percentage - 125-150 yards',
#  'Birdie or Better Percentage - < 125 yards',
#  'Scrambling from the Sand',
#  'Scrambling from the Rough',
#  'Scrambling from the Fringe',
#  'Scrambling from Other Locations',
#  'Scrambling from > 30 yards',
#  'Scrambling from 20-30 yards',
#  'Scrambling from 10-20 yards',
#  'Scrambling from < 10 yards',
#  'Sand Saves from 30+ yards',
#  'Sand Saves from 20-30 yards',
#  'Sand Saves from 10-20 yards',
#  'Sand Saves from < 10 yards',
#  'Proximity to Hole (ARG)',
#  'Proximity to Hole from Sand',
#  'Proximity to Hole from Rough',
#  'Proximity to Hole from Fringe',
#  'Proximity to Hole from Other Locations',
#  'Proximity to Hole from 30+ yards',
#  'Proximity to Hole from 20-30 yards',
#  'Proximity to Hole from 10-20 yards',
#  'Proximity to Hole from < 10 yards',
#  "GIR Putting - Inside 5'",
#  "GIR Putting - 5-10'",
#  "GIR Putting - 10-15'",
#  "GIR Putting - 15-20'",
#  "GIR Putting - 20-25'",
#  "GIR Putting - > 25'",
#  'Average Putting Distance - GIR 1 Putts',
#  'Average Putting Distance - GIR 2 Putts',
#  'Average Putting Distance - GIR 3 Putts',
#  'Average Putting Distance - GIR 3+ Putts',
#  '1-Putts per Round',
#  '2-Putts per Round',
#  '3-Putts per Round',
#  '3+ Putts per Round',
#  'Overall Putting Average',
#  "Putting from Inside 5'",
#  "Putting from 5-10'",
#  "Putting from - 10-15'",
#  "Putting from - 15-20'",
#  "Putting from - 20-25'",
#  "Putting from - > 25'",
#  'Average Putting Distance - All 1 putts',
#  'Average Putting Distance - All 2 putts',
#  'Average Putting Distance - All 3 putts',
#  'Average Putting Distance - All 3+ putts',
#  'One-Putt Percentage',
#  'One-Putt Percentage - Round 1',
#  'Going for the Green',
#  "Total 1 Putts - Inside 5'",
#  "Total 1 Putts - 5-10'",
#  "Total 1 Putts - 10-15'",
#  "Total 1 Putts - 15-20'",
#  "Total 1 Putts - 20-25'",
#  "Total 1 Putts - > 25'",
#  '3-Putt Avoidance',
#  'Fairway Proximity',
#  'Left Rough Proximity',
#  'Right Rough Proximity',
#  "Putts Made Per Event Over 10'",
#  "Putts Made Per Event Over 20'",
#  'Par 5 Going for the Green',
#  'Rough Proximity',
#  'Average Distance of Putts made',
#  "Total 3 Putts - Inside 5'",
#  "Total 3 Putts - 5-10'",
#  "Total 3 Putts - 10-15'",
#  "Total 3 Putts - 15-20'",
#  "Total 3 Putts - 20-25'",
#  "Total 3 Putts - > 25'",
#  'Par 4 Eagle Leaders',
#  'Par 5 Eagle Leaders',
#  'Consecutive Par 3 Birdies',
#  'Consecutive Par 4 Birdies',
#  'Consecutive Par 5 Birdies',
#  'Consecutive Holes Below Par',
#  '6-10 Final Round Performance',
#  'Driving Pct. 300+ (Measured)',
#  'Driving Pct. 280-300 (Measured)',
#  'Driving Pct. 260-280 (Measured)',
#  'Driving Pct. 240-260 (Measured)',
#  'Driving Pct. <= 240 (Measured)',
#  'Left Rough Tendency',
#  'Right Rough Tendency',
#  'Missed Fairway Percent - Other',
#  'Scrambling Rough (RTP Score)',
#  'Scrambling Fringe (RTP Score)',
#  'Scrambling > 30 yds (RTP Score)',
#  'Scrambling 20-30 yds (RTP Score)',
#  'Scrambling 10-20 yds (RTP Score)',
#  'Approaches Left Rough (RTP Score)',
#  'Approaches Right Rough (RTP Score)',
#  'Fairway Approach (RTP Score)',
#  'Approach < 125 yards (RTP Score)',
#  'Approach 125-150 yards (RTP Score)',
#  'Approach 150-175 yards (RTP Score)',
#  'Approach 175-200 yards (RTP Score)',
#  'Approach > 200 yards (RTP Score)',
#  'Scrambling Average Distance to Hole',
#  'Current Streak without a 3-Putt',
#  "Putting - Inside 10'",
#  "Putting from 4-8'",
#  'Going for the Green - Hit Green Pct.',
#  'Driving Pct. 300-320 (Measured)',
#  'Driving Pct. 320+ (Measured)',
#  'Longest Putts',
#  'Distance Analysis 260-280 yards - 3 Iron',
#  'Distance Analysis 260-280 yards - 4 Iron',
#  'Distance Analysis 260-280 yards - 5 Iron',
#  'Distance Analysis 260-280 yards - 6 Iron',
#  'Distance Analysis 260-280 yards - 7 Iron',
#  'Distance Analysis 260-280 yards - 8 Iron',
#  'Distance Analysis 240-260 yards - Fairway Wood',
#  'Distance Analysis 240-260 yards - 2 Iron',
#  'Distance Analysis 240-260 yards - 3 Iron',
#  'Distance Analysis 240-260 yards - 4 Iron',
#  'Distance Analysis 240-260 yards - 5 Iron',
#  'Distance Analysis 240-260 yards - 6 Iron',
#  'Distance Analysis 240-260 yards - 7 Iron',
#  'Distance Analysis 240-260 yards - 8 Iron',
#  'Distance Analysis 240-260 yards - 9 Iron',
#  'Distance Analysis 240-260 yards - Wedges',
#  'Distance Analysis 220-240 yards - Driver',
#  'Distance Analysis 220-240 yards - Fairway Wood',
#  'Distance Analysis 220-240 yards - 2 Iron',
#  'Distance Analysis 220-240 yards - 3 Iron',
#  'Distance Analysis 220-240 yards - 4 Iron',
#  'Distance Analysis 220-240 yards - 5 Iron',
#  'Distance Analysis 220-240 yards - 6 Iron',
#  'Distance Analysis 220-240 yards - 7 Iron',
#  'Distance Analysis 220-240 yards - 8 Iron',
#  'Distance Analysis 220-240 yards - Wedges',
#  'Distance Analysis 200-220 yards - Driver',
#  'Distance Analysis 200-220 yards - Fairway Wood',
#  'Distance Analysis 200-220 yards - 2 Iron',
#  'Distance Analysis 200-220 yards - 3 Iron',
#  'Distance Analysis 200-220 yards - 4 Iron',
#  'Distance Analysis 200-220 yards - 5 Iron',
#  'Distance Analysis 200-220 yards - 6 Iron',
#  'Distance Analysis 200-220 yards - 7 Iron',
#  'Distance Analysis 200-220 yards - 8 Iron',
#  'Distance Analysis 200-220 yards - 9 Iron',
#  'Distance Analysis 200-220 yards - Wedges',
#  'Distance Analysis 210-220 yards - Driver',
#  'Distance Analysis 210-220 yards - Fairway Wood',
#  'Distance Analysis 210-220 yards - 2 Iron',
#  'Distance Analysis 210-220 yards - 3 Iron',
#  'Distance Analysis 210-220 yards - 4 Iron',
#  'Distance Analysis 210-220 yards - 5 Iron',
#  'Distance Analysis 210-220 yards - 6 Iron',
#  'Distance Analysis 210-220 yards - 7 Iron',
#  'Distance Analysis 210-220 yards - 8 Iron',
#  'Distance Analysis 210-220 yards - 9 Iron',
#  'Distance Analysis 210-220 yards - Wedges',
#  'Distance Analysis 200-210 yards - Fairway Wood',
#  'Distance Analysis 200-210 yards - 2 Iron',
#  'Distance Analysis 200-210 yards - 3 Iron',
#  'Distance Analysis 200-210 yards - 4 Iron',
#  'Distance Analysis 200-210 yards - 5 Iron',
#  'Distance Analysis 200-210 yards - 6 Iron',
#  'Distance Analysis 200-210 yards - 7 Iron',
#  'Distance Analysis 190-200 yards - Fairway Wood',
#  'Distance Analysis 190-200 yards - 2 Iron',
#  'Distance Analysis 190-200 yards - 3 Iron',
#  'Distance Analysis 190-200 yards - 4 Iron',
#  'Distance Analysis 190-200 yards - 5 Iron',
#  'Distance Analysis 190-200 yards - 6 Iron',
#  'Distance Analysis 190-200 yards - 7 Iron',
#  'Distance Analysis 190-200 yards - 8 Iron',
#  'Distance Analysis 190-200 yards - 9 Iron',
#  'Distance Analysis 180-190 yards - Driver',
#  'Distance Analysis 180-190 yards - Fairway Wood',
#  'Distance Analysis 180-190 yards - 2 Iron',
#  'Distance Analysis 180-190 yards - 3 Iron',
#  'Distance Analysis 180-190 yards - 4 Iron',
#  'Distance Analysis 180-190 yards - 5 Iron',
#  'Distance Analysis 180-190 yards - 6 Iron',
#  'Distance Analysis 180-190 yards - 7 Iron',
#  'Distance Analysis 180-190 yards - 8 Iron',
#  'Distance Analysis 180-190 yards - 9 Iron',
#  'Distance Analysis 180-190 yards - Wedges',
#  'Distance Analysis 170-180 yards - Driver',
#  'Distance Analysis 170-180 yards - Fairway Wood',
#  'Distance Analysis 170-180 yards - 2 Iron',
#  'Distance Analysis 170-180 yards - 3 Iron',
#  'Distance Analysis 170-180 yards - 4 Iron',
#  'Distance Analysis 170-180 yards - 6 Iron',
#  'Distance Analysis 170-180 yards - 7 Iron',
#  'Distance Analysis 170-180 yards - 8 Iron',
#  'Distance Analysis 170-180 yards - 9 Iron',
#  'Distance Analysis 170-180 yards - Wedges',
#  'Distance Analysis 160-170 yards - Fairway Wood',
#  'Distance Analysis 160-170 yards - 3 Iron',
#  'Distance Analysis 160-170 yards - 4 Iron',
#  'Distance Analysis 160-170 yards - 5 Iron',
#  'Distance Analysis 160-170 yards - 6 Iron',
#  'Distance Analysis 160-170 yards - 7 Iron',
#  'Distance Analysis 160-170 yards - 8 Iron',
#  'Distance Analysis 160-170 yards - 9 Iron',
#  'Distance Analysis 160-170 yards - Wedges',
#  'Distance Analysis 150-160 yards - 5 Iron',
#  'Distance Analysis 150-160 yards - 6 Iron',
#  'Distance Analysis 150-160 yards - 7 Iron',
#  'Distance Analysis 150-160 yards - 8 Iron',
#  'Distance Analysis 150-160 yards - 9 Iron',
#  'Distance Analysis 150-160 yards - Wedges',
#  'Distance Analysis 140-150 yards - 5 Iron',
#  'Distance Analysis 140-150 yards - 6 Iron',
#  'Distance Analysis 140-150 yards - 7 Iron',
#  'Distance Analysis 140-150 yards - 8 Iron',
#  'Distance Analysis 140-150 yards - 9 Iron',
#  'Distance Analysis 140-150 yards - Wedges',
#  'Distance Analysis 130-140 yards - 4 Iron',
#  'Distance Analysis 130-140 yards - 6 Iron',
#  'Distance Analysis 130-140 yards - 7 Iron',
#  'Distance Analysis 130-140 yards - 8 Iron',
#  'Distance Analysis 130-140 yards - 9 Iron',
#  'Distance Analysis 130-140 yards - Wedges',
#  'Distance Analysis 120-130 yards - Fairway Wood',
#  'Distance Analysis 120-130 yards - 6 Iron',
#  'Distance Analysis 120-130 yards - 8 Iron',
#  'Distance Analysis 120-130 yards - 9 Iron',
#  'Distance Analysis 120-130 yards - Wedges',
#  'Distance Analysis 110-120 yards - Fairway Wood',
#  'Distance Analysis 110-120 yards - 7 Iron',
#  'Distance Analysis 110-120 yards - 9 Iron',
#  'Distance Analysis 110-120 yards - Wedges',
#  'Distance Analysis 100-110 yards - Fairway Wood',
#  'Distance Analysis 100-110 yards - 9 Iron',
#  'Distance Analysis 100-110 yards - Wedges',
#  'Distance Analysis < 80 yards - Fairway Wood',
#  'Distance Analysis < 80 yards - 2 Iron',
#  'Distance Analysis < 80 yards - Wedges',
#  'Average Approach Shot Distance',
#  "Putting from 5-15'",
#  "Putting from 15-25'",
#  'Approaches from inside 100 yards',
#  'GIR Percentage - < 100 yards',
#  'Approaches from > 100 yards',
#  'GIR Percentage - 100+ yards',
#  'Birdie or Better Percentage - Fairway',
#  'Birdie or Better Percentage - Left Rough',
#  'Birdie or Better Percentage - Right Rough',
#  'Birdie or Better Percentage - Rough',
#  'Percentage of Available Purse Won',
#  'Average Approach Distance - Birdie or Better',
#  'Average Approach Distance - Par',
#  'Average Approach Distance - Bogey or Worse',
#  'Percentage of Yardage covered by Tee Shots',
#  "Percentage of Yardage covered by Tee Shots - Par 4's",
#  "Percentage of Yardage covered by Tee Shots - Par 5's",
#  'Scoring Rating',
#  'Last 5 Events - Power',
#  'Last 5 Events - Accuracy',
#  'Last 5 Events - Short Game',
#  'Last 5 Events - Putting',
#  'Last 5 Events - Scoring',
#  'Last 15 Events - Power',
#  'Last 15 Events - Accuracy',
#  'Last 15 Events - Short Game',
#  'Last 15 Events - Putting',
#  'Last 15 Events - Scoring',
#  'Going for the Green - Birdie or Better',
#  'Approaches from 200-225 yards',
#  'Approaches from 225-250 yards',
#  'Approaches from 250-275 yards',
#  'Approaches from > 275 yards',
#  'Approaches from 50-75 yards (Rgh)',
#  'Approaches from 75-100 yards (Rgh)',
#  'Approaches from 100-125 yards (Rgh)',
#  'Approaches from 50-125 yards (Rgh)',
#  'Approaches from 125-150 yards (Rgh)',
#  'Approaches from 150-175 yards (Rgh)',
#  'Approaches from 175-200 yards (Rgh)',
#  'Approaches from > 200 yards (Rgh)',
#  'Approaches from inside 100 yards (Rgh)',
#  'Approaches from > 100 yards (Rgh)',
#  'Approaches from 200-225 yards (Rgh)',
#  'Approaches from 225-250 yards (Rgh)',
#  'Approaches from 250-275 yards (Rgh)',
#  'Approaches from > 275 yards (Rgh)',
#  'Approach 200-225 yards (RTP)',
#  'Approach 225-250 yards (RTP)',
#  'Approach 250-275 yards (RTP)',
#  'Approach > 275 yards (RTP)',
#  'Approaches 50-75 yards-Rgh (RTP)',
#  'Approaches 75-100 yards-Rgh (RTP)',
#  'Approaches 100-125 yards-Rgh (RTP)',
#  'Approaches 50-125 yards-Rgh (RTP)',
#  'Approaches 125-150 yards-Rgh (RTP)',
#  'Approaches 150-175 yards-Rgh (RTP)',
#  'Approaches 175-200 yards-Rgh (RTP)',
#  'Approaches > 200 yards-Rgh (RTP)',
#  'Approaches < 100 yards-Rgh (RTP)',
#  'Approaches > 100 yards-Rgh (RTP)',
#  'Approaches 200-225 yards-Rgh (RTP)',
#  'Approaches 225-250 yards-Rgh (RTP)',
#  'Approaches 250-275 yards-Rgh (RTP)',
#  'Approaches > 275 yards-Rgh (RTP)',
#  'FedExCup Season Points',
#  'FedExCup Playoffs Points',
#  'FedExCup Bonus Money',
#  'FedExCup Season Points for Non-Members',
#  'Club Head Speed',
#  'Ball Speed',
#  'Smash Factor',
#  'Launch Angle',
#  'Spin Rate',
#  'Distance to Apex',
#  'Apex Height',
#  'Hang Time',
#  'Carry Distance',
#  'Carry Efficiency',
#  'Total Distance Efficiency',
#  'Total Driving Efficiency',
#  'Bogey Avoidance',
#  'Birdie to Bogey Ratio',
#  'Reverse Bounce Back',
#  'Stroke Differential Field Average',
#  'Bogey Average',
#  'Distance from Edge of Fairway',
#  'Distance from Center of Fairway',
#  'Left Tendency',
#  'Right Tendency',
#  'Average Going for it Shot Distance (in Yards)',
#  "Putting from 3-5'",
#  'Total Putting',
#  "Putting from - > 20'",
#  'Average Distance to Hole After Tee Shot',
#  'Average Distance after Going for it Shot',
#  'Driving Pct. 300-320 (All Drives)',
#  'Driving Pct. 320+ (All Drives)',
#  'GIR Pct. - Fairway Bunker',
#  'Rough Tendency',
#  'Greens or Fringe in Regulation',
#  'Good Drive Percentage',
#  'Bonus Putting',
#  'Average Distance of Birdie putts made',
#  'Average Distance of Eagle putts made',
#  'Money Leaders - Fall Series',
#  'Percentage of potential money won',
#  '% of Potential Pts won - FedExCup Regular Season',
#  '% of Potential Pts won - FedExCup Playoffs',
#  'FedExCup Points per Event Leaders',
#  'SG: Putting',
#  'SG: Off-the-Tee',
#  'SG: Approach-the-Green',
#  'SG: Around-the-Green',
#  'Non-WGC FedExCup Season Points for Non-Members',
#  'FedExCup Standings',
#  'Consecutive Birdies Streak',
#  'Consecutive Birdies/Eagles streak',
#  'SG: Tee-to-Green',
#  'SG: Total',
#  'Non-Member Off+WGC Earnings',
#  'Approach 100-125 yards (RTP Score)',
#  'Approach 75-100 yards (RTP Score)',
#  'Approach 50-75 yards (RTP Score)',
#  "3-Putt Avoidance - Inside 5'",
#  "3-Putt Avoidance - 5-10'",
#  "3-Putt Avoidance - 10-15'",
#  "GIR Putting Avg - 25-30'",
#  "GIR Putting Avg - 30-35'",
#  "GIR Putting Avg - > 35'",
#  'Approaches from 100-125 yards',
#  'Approaches from 75-100 yards',
#  'Approaches from 50-75 yards',
#  'GIR Percentage - 100-125 yards',
#  'GIR Percentage - 75-100 yards',
#  'GIR Percentage - < 75 yards',
#  'Right Rough Tendency (RTP Score)',
#  'Left Rough Tendency (RTP Score)',
#  'Power Rating',
#  'Accuracy Rating',
#  'Short Game Rating',
#  'Putting Rating',
#  'Fairway Bunker Tendency']

# %%
stat_list = ['Driving Distance',
 'Driving Accuracy Percentage',
 'Greens in Regulation Percentage',
 'Putting Average',
 'Scoring Average (Actual)',
 'Money Leaders',
 'Sand Save Percentage',
 'Putts Per Round',
 'Scoring Average',
 'All-Around Ranking',
 'Scrambling',
 'Putts made Distance',
 'Money per Event Leaders',
 'World Money List',
 'Ball Striking',
 'Longest Drives',
 'GIR Percentage from Fairway',
 'Total Money (Official and Unofficial)',
 'GIR Percentage from Other than Fairway',
 'Average Distance of Putts made',
 'Last 15 Events - Power',
 'Last 15 Events - Accuracy',
 'Last 15 Events - Short Game',
 'Last 15 Events - Putting',
 'Last 15 Events - Scoring',
 'Going for the Green - Birdie or Better',
 'Short Game Rating',
 'Putting Rating',
 'Fairway Bunker Tendency']

# %%
df = df[df['Statistic'].isin(stat_list)]

# %%
df.isnull().sum()
# Out:
# Player Name      0
# Season           0
# Statistic        0
# Variable         0
# Value          881
# dtype: int64

# %%
df.shape
# Out:
# (189350, 5)

# %%
df.drop(columns='Statistic')
# Out:
#              Player Name  Season                                     Variable  \
# 0        Robert Garrigus    2010                  Driving Distance - (ROUNDS)
# 1           Bubba Watson    2010                  Driving Distance - (ROUNDS)
# 2         Dustin Johnson    2010                  Driving Distance - (ROUNDS)
# 3        Brett Wetterich    2010                  Driving Distance - (ROUNDS)
# 4            J.B. Holmes    2010                  Driving Distance - (ROUNDS)
# ...                  ...     ...                                          ...
# 2740398       Ben Martin    2018  Fairway Bunker Tendency - (RELATIVE TO PAR)
# 2740399     Robert Streb    2018  Fairway Bunker Tendency - (RELATIVE TO PAR)
# 2740400       Andrew Yun    2018  Fairway Bunker Tendency - (RELATIVE TO PAR)
# 2740401     Nate Lashley    2018  Fairway Bunker Tendency - (RELATIVE TO PAR)
# 2740402    Martin Flores    2018  Fairway Bunker Tendency - (RELATIVE TO PAR)
#
#           Value
# 0            71
# 1            77
# 2            83
# 3            54
# 4           100
# ...         ...
# 2740398  +0.209
# 2740399  +0.239
# 2740400  +0.225
# 2740401  +0.143
# 2740402  +0.181
#
# [189350 rows x 4 columns]

# %%
df['Name_Year'] = df['Player Name'] + df['Season'].astype('str')

# %%
df.head()
# Out:
#        Player Name  Season         Statistic                     Variable  \
# 0  Robert Garrigus    2010  Driving Distance  Driving Distance - (ROUNDS)
# 1     Bubba Watson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 2   Dustin Johnson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 3  Brett Wetterich    2010  Driving Distance  Driving Distance - (ROUNDS)
# 4      J.B. Holmes    2010  Driving Distance  Driving Distance - (ROUNDS)
#
#   Value            Name_Year
# 0    71  Robert Garrigus2010
# 1    77     Bubba Watson2010
# 2    83   Dustin Johnson2010
# 3    54  Brett Wetterich2010
# 4   100      J.B. Holmes2010

# %%
df.isnull().sum()
# Out:
# Player Name      0
# Season           0
# Statistic        0
# Variable         0
# Value          881
# Name_Year        0
# dtype: int64

# %%
df.shape
# Out:
# (189350, 6)

# %%
df = df.pivot(index='Name_Year', columns='Variable', values='Value')
df
# Out:
# Variable           All-Around Ranking - (EVENTS) All-Around Ranking - (TOTAL)  \
# Name_Year
# A.J. McInerney2018                           NaN                          NaN
# Aaron Baddeley2010                            26                          537
# Aaron Baddeley2011                            22                          485
# Aaron Baddeley2012                            22                          815
# Aaron Baddeley2013                            24                          755
# ...                                          ...                          ...
# Zaw Moe2011                                  NaN                          NaN
# Zecheng Dou2015                              NaN                          NaN
# Zecheng Dou2016                              NaN                          NaN
# Zecheng Dou2017                              NaN                          NaN
# Zecheng Dou2018                               23                        1,323
#
# Variable           Average Distance of Putts made - (AVG DIST.)  \
# Name_Year
# A.J. McInerney2018                                          NaN
# Aaron Baddeley2010                                        4' 5"
# Aaron Baddeley2011                                        4' 3"
# Aaron Baddeley2012                                        4' 2"
# Aaron Baddeley2013                                        4' 4"
# ...                                                         ...
# Zaw Moe2011                                                 NaN
# Zecheng Dou2015                                             NaN
# Zecheng Dou2016                                             NaN
# Zecheng Dou2017                                             NaN
# Zecheng Dou2018                                           4' 0"
#
# Variable           Average Distance of Putts made - (AVG)  \
# Name_Year
# A.J. McInerney2018                                    NaN
# Aaron Baddeley2010                                 78' 7"
# Aaron Baddeley2011                                 75' 2"
# Aaron Baddeley2012                                 74' 9"
# Aaron Baddeley2013                                 76' 7"
# ...                                                   ...
# Zaw Moe2011                                           NaN
# Zecheng Dou2015                                       NaN
# Zecheng Dou2016                                       NaN
# Zecheng Dou2017                                       NaN
# Zecheng Dou2018                                    71' 3"
#
# Variable           Average Distance of Putts made - (BEST ROUND)  \
# Name_Year
# A.J. McInerney2018                                           NaN
# Aaron Baddeley2010                                       156' 8"
# Aaron Baddeley2011                                       148' 9"
# Aaron Baddeley2012                                       139' 6"
# Aaron Baddeley2013                                       154' 9"
# ...                                                          ...
# Zaw Moe2011                                                  NaN
# Zecheng Dou2015                                              NaN
# Zecheng Dou2016                                              NaN
# Zecheng Dou2017                                              NaN
# Zecheng Dou2018                                          128' 9"
#
# Variable           Average Distance of Putts made - (ROUNDS)  \
# Name_Year
# A.J. McInerney2018                                       NaN
# Aaron Baddeley2010                                        94
# Aaron Baddeley2011                                        77
# Aaron Baddeley2012                                        73
# Aaron Baddeley2013                                        68
# ...                                                      ...
# Zaw Moe2011                                              NaN
# Zecheng Dou2015                                          NaN
# Zecheng Dou2016                                          NaN
# Zecheng Dou2017                                          NaN
# Zecheng Dou2018                                           53
#
# Variable           Average Distance of Putts made - (TOTAL DIST. (INCHES))  \
# Name_Year
# A.J. McInerney2018                                                NaN
# Aaron Baddeley2010                                             82,980
# Aaron Baddeley2011                                             55,898
# Aaron Baddeley2012                                             49,343
# Aaron Baddeley2013                                             54,200
# ...                                                               ...
# Zaw Moe2011                                                       NaN
# Zecheng Dou2015                                                   NaN
# Zecheng Dou2016                                                   NaN
# Zecheng Dou2017                                                   NaN
# Zecheng Dou2018                                                30,780
#
# Variable           Average Distance of Putts made - (TOTAL ROUNDS)  \
# Name_Year
# A.J. McInerney2018                                             NaN
# Aaron Baddeley2010                                              88
# Aaron Baddeley2011                                              62
# Aaron Baddeley2012                                              55
# Aaron Baddeley2013                                              59
# ...                                                            ...
# Zaw Moe2011                                                    NaN
# Zecheng Dou2015                                                NaN
# Zecheng Dou2016                                                NaN
# Zecheng Dou2017                                                NaN
# Zecheng Dou2018                                                 36
#
# Variable           Ball Striking - (GIR RANK) Ball Striking - (ROUNDS)  ...  \
# Name_Year                                                               ...
# A.J. McInerney2018                        NaN                      NaN  ...
# Aaron Baddeley2010                        164                       94  ...
# Aaron Baddeley2011                         97                       77  ...
# Aaron Baddeley2012                        190                       73  ...
# Aaron Baddeley2013                        178                       68  ...
# ...                                       ...                      ...  ...
# Zaw Moe2011                               NaN                      NaN  ...
# Zecheng Dou2015                           NaN                      NaN  ...
# Zecheng Dou2016                           NaN                      NaN  ...
# Zecheng Dou2017                           NaN                      NaN  ...
# Zecheng Dou2018                           157                       53  ...
#
# Variable           Scrambling - (%) Scrambling - (MISSED GIR)  \
# Name_Year
# A.J. McInerney2018              NaN                       NaN
# Aaron Baddeley2010            57.10                       599
# Aaron Baddeley2011            59.44                       466
# Aaron Baddeley2012            59.85                       543
# Aaron Baddeley2013            57.72                       499
# ...                             ...                       ...
# Zaw Moe2011                     NaN                       NaN
# Zecheng Dou2015                 NaN                       NaN
# Zecheng Dou2016                 NaN                       NaN
# Zecheng Dou2017                 NaN                       NaN
# Zecheng Dou2018               51.56                       320
#
# Variable           Scrambling - (PAR OR BETTER) Scrambling - (ROUNDS)  \
# Name_Year
# A.J. McInerney2018                          NaN                   NaN
# Aaron Baddeley2010                          342                    94
# Aaron Baddeley2011                          277                    77
# Aaron Baddeley2012                          325                    73
# Aaron Baddeley2013                          288                    68
# ...                                         ...                   ...
# Zaw Moe2011                                 NaN                   NaN
# Zecheng Dou2015                             NaN                   NaN
# Zecheng Dou2016                             NaN                   NaN
# Zecheng Dou2017                             NaN                   NaN
# Zecheng Dou2018                             165                    53
#
# Variable           Short Game Rating - (EVENTS) Short Game Rating - (RATING)  \
# Name_Year
# A.J. McInerney2018                            2                          5.1
# Aaron Baddeley2010                           17                          6.4
# Aaron Baddeley2011                           15                          7.0
# Aaron Baddeley2012                           12                          6.6
# Aaron Baddeley2013                            9                          6.7
# ...                                         ...                          ...
# Zaw Moe2011                                 NaN                          NaN
# Zecheng Dou2015                             NaN                          NaN
# Zecheng Dou2016                             NaN                          NaN
# Zecheng Dou2017                             NaN                          NaN
# Zecheng Dou2018                               3                          6.2
#
# Variable           Total Money (Official and Unofficial) - (EVENTS)  \
# Name_Year
# A.J. McInerney2018                                                4
# Aaron Baddeley2010                                               26
# Aaron Baddeley2011                                               24
# Aaron Baddeley2012                                               22
# Aaron Baddeley2013                                               24
# ...                                                             ...
# Zaw Moe2011                                                     NaN
# Zecheng Dou2015                                                   1
# Zecheng Dou2016                                                   1
# Zecheng Dou2017                                                   1
# Zecheng Dou2018                                                  23
#
# Variable           Total Money (Official and Unofficial) - (MONEY)  \
# Name_Year
# A.J. McInerney2018                                        $164,923
# Aaron Baddeley2010                                         879,317
# Aaron Baddeley2011                                      $3,157,193
# Aaron Baddeley2012                                      $1,215,753
# Aaron Baddeley2013                                        $721,024
# ...                                                            ...
# Zaw Moe2011                                                    NaN
# Zecheng Dou2015                                            $41,625
# Zecheng Dou2016                                            $49,000
# Zecheng Dou2017                                            $62,000
# Zecheng Dou2018                                            $90,993
#
# Variable           World Money List - (EVENTS) World Money List - (MONEY)
# Name_Year
# A.J. McInerney2018                         NaN                        NaN
# Aaron Baddeley2010                          27                    879,317
# Aaron Baddeley2011                          26                 $3,321,105
# Aaron Baddeley2012                         NaN                        NaN
# Aaron Baddeley2013                         NaN                        NaN
# ...                                        ...                        ...
# Zaw Moe2011                                 16                    $92,947
# Zecheng Dou2015                            NaN                        NaN
# Zecheng Dou2016                            NaN                        NaN
# Zecheng Dou2017                            NaN                        NaN
# Zecheng Dou2018                            NaN                        NaN
#
# [4845 rows x 105 columns]

# %%
df.isnull().sum()
# Out:
# Variable
# All-Around Ranking - (EVENTS)                       3167
# All-Around Ranking - (TOTAL)                        3167
# Average Distance of Putts made - (AVG DIST.)        3167
# Average Distance of Putts made - (AVG)              3167
# Average Distance of Putts made - (BEST ROUND)       3167
#                                                     ...
# Short Game Rating - (RATING)                        2018
# Total Money (Official and Unofficial) - (EVENTS)    1164
# Total Money (Official and Unofficial) - (MONEY)     1164
# World Money List - (EVENTS)                         3272
# World Money List - (MONEY)                          3272
# Length: 105, dtype: int64

# %%
df = df.dropna(subset=['Driving Accuracy Percentage - (%)'])

# %%
column_list = df.columns.tolist()
column_list
# Out:
# ['All-Around Ranking - (EVENTS)',
#  'All-Around Ranking - (TOTAL)',
#  'Average Distance of Putts made - (AVG DIST.)',
#  'Average Distance of Putts made - (AVG)',
#  'Average Distance of Putts made - (BEST ROUND)',
#  'Average Distance of Putts made - (ROUNDS)',
#  'Average Distance of Putts made - (TOTAL DIST. (INCHES))',
#  'Average Distance of Putts made - (TOTAL ROUNDS)',
#  'Ball Striking - (GIR RANK)',
#  'Ball Striking - (ROUNDS)',
#  'Ball Striking - (TOTAL DRV RANK)',
#  'Ball Striking - (VALUE)',
#  'Driving Accuracy Percentage - (%)',
#  'Driving Accuracy Percentage - (FAIRWAYS HIT)',
#  'Driving Accuracy Percentage - (POSSIBLE FAIRWAYS)',
#  'Driving Accuracy Percentage - (ROUNDS)',
#  'Driving Distance - (AVG.)',
#  'Driving Distance - (ROUNDS)',
#  'Driving Distance - (TOTAL DISTANCE)',
#  'Driving Distance - (TOTAL DRIVES)',
#  'Fairway Bunker Tendency - (%)',
#  'Fairway Bunker Tendency - (POSSIBLE FWYS)',
#  'Fairway Bunker Tendency - (RELATIVE TO PAR)',
#  'Fairway Bunker Tendency - (ROUNDS)',
#  'Fairway Bunker Tendency - (TOTAL FAIRWAY BUNKERS)',
#  'GIR Percentage from Fairway - (# OF HOLES)',
#  'GIR Percentage from Fairway - (%)',
#  'GIR Percentage from Fairway - (GREENS HIT)',
#  'GIR Percentage from Fairway - (ROUNDS)',
#  'GIR Percentage from Other than Fairway - (# OF HOLES)',
#  'GIR Percentage from Other than Fairway - (%)',
#  'GIR Percentage from Other than Fairway - (GREENS HIT)',
#  'GIR Percentage from Other than Fairway - (ROUNDS)',
#  'Going for the Green - Birdie or Better - (# OF BIRDIE OR BETTER)',
#  'Going for the Green - Birdie or Better - (%)',
#  'Going for the Green - Birdie or Better - (ATTEMPTS)',
#  'Going for the Green - Birdie or Better - (ROUNDS)',
#  'Going for the Green - Birdie or Better - (RTP-NOT GOING FOR THE GRN)',
#  'Going for the Green - Birdie or Better - (RTP-SUCCESSES)',
#  'Greens in Regulation Percentage - (# HOLES)',
#  'Greens in Regulation Percentage - (%)',
#  'Greens in Regulation Percentage - (GREENS HIT)',
#  'Greens in Regulation Percentage - (RELATIVE/PAR)',
#  'Greens in Regulation Percentage - (ROUNDS)',
#  'Last 15 Events - Accuracy - (EVENTS)',
#  'Last 15 Events - Accuracy - (RATING)',
#  'Last 15 Events - Power - (EVENTS)',
#  'Last 15 Events - Power - (RATING)',
#  'Last 15 Events - Putting - (EVENTS)',
#  'Last 15 Events - Putting - (RATING)',
#  'Last 15 Events - Scoring - (EVENTS)',
#  'Last 15 Events - Scoring - (RATING)',
#  'Last 15 Events - Short Game - (EVENTS)',
#  'Last 15 Events - Short Game - (RATING)',
#  'Longest Drives - (COURSE)',
#  'Longest Drives - (DISTANCE)',
#  'Longest Drives - (HOLE)',
#  'Longest Drives - (ROUND)',
#  'Longest Drives - (ROUNDS)',
#  'Longest Drives - (TOURNAMENT)',
#  'Money Leaders - (EVENTS)',
#  'Money Leaders - (MONEY)',
#  'Money Leaders - (YTD VICTORIES)',
#  'Money per Event Leaders - (EVENTS)',
#  'Money per Event Leaders - (MONEY PER EVENT)',
#  'Money per Event Leaders - (TOTAL MONEY)',
#  'Putting Average - (AVG)',
#  'Putting Average - (BIRDIE CONVERSION)',
#  'Putting Average - (GIR PUTTS)',
#  'Putting Average - (GIR RANK)',
#  'Putting Average - (GREENS HIT)',
#  'Putting Average - (ROUNDS)',
#  'Putting Rating - (EVENTS)',
#  'Putting Rating - (RATING)',
#  'Putts Per Round - (AVG)',
#  'Putts Per Round - (LOW TOTAL PUTTS)',
#  'Putts Per Round - (ROUNDS)',
#  'Putts Per Round - (TOTAL PUTTS)',
#  'Putts Per Round - (TOTAL ROUNDS)',
#  'Putts made Distance - (DISTANCE IN INCHES)',
#  'Putts made Distance - (EVENTS)',
#  'Sand Save Percentage - (# BUNKERS)',
#  'Sand Save Percentage - (# SAVES)',
#  'Sand Save Percentage - (%)',
#  'Sand Save Percentage - (ROUNDS)',
#  'Sand Save Percentage - (TOTAL O/U PAR)',
#  'Scoring Average (Actual) - (AVG)',
#  'Scoring Average (Actual) - (ROUNDS)',
#  'Scoring Average (Actual) - (TOTAL ROUNDS)',
#  'Scoring Average (Actual) - (TOTAL STROKES)',
#  'Scoring Average - (AVG)',
#  'Scoring Average - (ROUNDS)',
#  'Scoring Average - (TOTAL ADJUSTMENT)',
#  'Scoring Average - (TOTAL ROUNDS)',
#  'Scoring Average - (TOTAL STROKES)',
#  'Scrambling - (%)',
#  'Scrambling - (MISSED GIR)',
#  'Scrambling - (PAR OR BETTER)',
#  'Scrambling - (ROUNDS)',
#  'Short Game Rating - (EVENTS)',
#  'Short Game Rating - (RATING)',
#  'Total Money (Official and Unofficial) - (EVENTS)',
#  'Total Money (Official and Unofficial) - (MONEY)',
#  'World Money List - (EVENTS)',
#  'World Money List - (MONEY)']

# %%
df['Driving Accuracy Percentage - (%)'].isnull().sum()
# Out:
# 0

# %%
col_list = ['Average Distance of Putts made - (AVG DIST.)',
       'Average Distance of Putts made - (AVG)', 'Ball Striking - (GIR RANK)',
       'Ball Striking - (TOTAL DRV RANK)', 'Driving Accuracy Percentage - (%)',
       'Driving Distance - (AVG.)', 'GIR Percentage from Fairway - (%)',
       'GIR Percentage from Other than Fairway - (%)',
       'Going for the Green - Birdie or Better - (%)',
       'Greens in Regulation Percentage - (%)',
        'Putting Average - (AVG)',
       'Putting Average - (BIRDIE CONVERSION)',
       'Putting Average - (GIR PUTTS)', 'Putting Average - (GIR RANK)',
        'Putts Per Round - (AVG)',
       'Putts made Distance - (DISTANCE IN INCHES)',
       'Sand Save Percentage - (%)', 
       'Short Game Rating - (RATING)',
            'Scrambling - (%)',
       'Total Money (Official and Unofficial) - (MONEY)']

# %%
df = df[col_list]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, Aaron Baddeley2010 to Zecheng Dou2018
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Average Distance of Putts made - (AVG DIST.)     1678 non-null   object
#  1   Average Distance of Putts made - (AVG)           1678 non-null   object
#  2   Ball Striking - (GIR RANK)                       1678 non-null   object
#  3   Ball Striking - (TOTAL DRV RANK)                 1678 non-null   object
#  4   Driving Accuracy Percentage - (%)                1678 non-null   object
#  5   Driving Distance - (AVG.)                        1678 non-null   object
#  6   GIR Percentage from Fairway - (%)                1678 non-null   object
#  7   GIR Percentage from Other than Fairway - (%)     1678 non-null   object
#  8   Going for the Green - Birdie or Better - (%)     1678 non-null   object
#  9   Greens in Regulation Percentage - (%)            1678 non-null   object
#  10  Putting Average - (AVG)                          1678 non-null   object
#  11  Putting Average - (BIRDIE CONVERSION)            1678 non-null   object
#  12  Putting Average - (GIR PUTTS)                    1678 non-null   object
#  13  Putting Average - (GIR RANK)                     1678 non-null   object
#  14  Putts Per Round - (AVG)                          1678 non-null   object
#  15  Putts made Distance - (DISTANCE IN INCHES)       1678 non-null   object
#  16  Sand Save Percentage - (%)                       1678 non-null   object
#  17  Short Game Rating - (RATING)                     1678 non-null   object
#  18  Scrambling - (%)                                 1678 non-null   object
#  19  Total Money (Official and Unofficial) - (MONEY)  1678 non-null   object
# dtypes: object(20)
# memory usage: 275.3+ KB

# %%
df['Year'] = df.index.str[-4:]

# %%
df['Name_Year'] = df.index.str[:-4]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, Aaron Baddeley2010 to Zecheng Dou2018
# Data columns (total 22 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Average Distance of Putts made - (AVG DIST.)     1678 non-null   object
#  1   Average Distance of Putts made - (AVG)           1678 non-null   object
#  2   Ball Striking - (GIR RANK)                       1678 non-null   object
#  3   Ball Striking - (TOTAL DRV RANK)                 1678 non-null   object
#  4   Driving Accuracy Percentage - (%)                1678 non-null   object
#  5   Driving Distance - (AVG.)                        1678 non-null   object
#  6   GIR Percentage from Fairway - (%)                1678 non-null   object
#  7   GIR Percentage from Other than Fairway - (%)     1678 non-null   object
#  8   Going for the Green - Birdie or Better - (%)     1678 non-null   object
#  9   Greens in Regulation Percentage - (%)            1678 non-null   object
#  10  Putting Average - (AVG)                          1678 non-null   object
#  11  Putting Average - (BIRDIE CONVERSION)            1678 non-null   object
#  12  Putting Average - (GIR PUTTS)                    1678 non-null   object
#  13  Putting Average - (GIR RANK)                     1678 non-null   object
#  14  Putts Per Round - (AVG)                          1678 non-null   object
#  15  Putts made Distance - (DISTANCE IN INCHES)       1678 non-null   object
#  16  Sand Save Percentage - (%)                       1678 non-null   object
#  17  Short Game Rating - (RATING)                     1678 non-null   object
#  18  Scrambling - (%)                                 1678 non-null   object
#  19  Total Money (Official and Unofficial) - (MONEY)  1678 non-null   object
#  20  Year                                             1678 non-null   object
#  21  Name_Year                                        1678 non-null   object
# dtypes: object(22)
# memory usage: 301.5+ KB

# %%
df.columns
# Out:
# Index(['Average Distance of Putts made - (AVG DIST.)',
#        'Average Distance of Putts made - (AVG)', 'Ball Striking - (GIR RANK)',
#        'Ball Striking - (TOTAL DRV RANK)', 'Driving Accuracy Percentage - (%)',
#        'Driving Distance - (AVG.)', 'GIR Percentage from Fairway - (%)',
#        'GIR Percentage from Other than Fairway - (%)',
#        'Going for the Green - Birdie or Better - (%)',
#        'Greens in Regulation Percentage - (%)', 'Putting Average - (AVG)',
#        'Putting Average - (BIRDIE CONVERSION)',
#        'Putting Average - (GIR PUTTS)', 'Putting Average - (GIR RANK)',
#        'Putts Per Round - (AVG)', 'Putts made Distance - (DISTANCE IN INCHES)',
#        'Sand Save Percentage - (%)', 'Short Game Rating - (RATING)',
#        'Scrambling - (%)', 'Total Money (Official and Unofficial) - (MONEY)',
#        'Year', 'Name_Year'],
#       dtype='object', name='Variable')

# %%
df = df.apply(lambda x: x.str.replace(',', ''))
df = df.apply(lambda x: x.str.replace("'",''))
df = df.apply(lambda x: x.str.replace("$",''))
df = df.apply(lambda x: x.str.replace('"',''))
df = df.apply(lambda x: x.str.replace(' ','.'))
df = df.apply(lambda x: x.str.replace('T',''))

# %%
df = df.drop(columns='Name_Year')

# %%
df.isnull().sum()
# Out:
# Variable
# Average Distance of Putts made - (AVG DIST.)       0
# Average Distance of Putts made - (AVG)             0
# Ball Striking - (GIR RANK)                         0
# Ball Striking - (TOTAL DRV RANK)                   0
# Driving Accuracy Percentage - (%)                  0
# Driving Distance - (AVG.)                          0
# GIR Percentage from Fairway - (%)                  0
# GIR Percentage from Other than Fairway - (%)       0
# Going for the Green - Birdie or Better - (%)       0
# Greens in Regulation Percentage - (%)              0
# Putting Average - (AVG)                            0
# Putting Average - (BIRDIE CONVERSION)              0
# Putting Average - (GIR PUTTS)                      0
# Putting Average - (GIR RANK)                       0
# Putts Per Round - (AVG)                            0
# Putts made Distance - (DISTANCE IN INCHES)         0
# Sand Save Percentage - (%)                         0
# Short Game Rating - (RATING)                       0
# Scrambling - (%)                                   0
# Total Money (Official and Unofficial) - (MONEY)    0
# Year                                               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Average Distance of Putts made - (AVG DIST.)',
#        'Average Distance of Putts made - (AVG)', 'Ball Striking - (GIR RANK)',
#        'Ball Striking - (TOTAL DRV RANK)', 'Driving Accuracy Percentage - (%)',
#        'Driving Distance - (AVG.)', 'GIR Percentage from Fairway - (%)',
#        'GIR Percentage from Other than Fairway - (%)',
#        'Going for the Green - Birdie or Better - (%)',
#        'Greens in Regulation Percentage - (%)', 'Putting Average - (AVG)',
#        'Putting Average - (BIRDIE CONVERSION)',
#        'Putting Average - (GIR PUTTS)', 'Putting Average - (GIR RANK)',
#        'Putts Per Round - (AVG)', 'Putts made Distance - (DISTANCE IN INCHES)',
#        'Sand Save Percentage - (%)', 'Short Game Rating - (RATING)',
#        'Scrambling - (%)', 'Total Money (Official and Unofficial) - (MONEY)',
#        'Year'],
#       dtype='object', name='Variable')

# %%
col = ['Average Distance of Putts made - (AVG DIST.)',
       'Average Distance of Putts made - (AVG)', 'Ball Striking - (GIR RANK)',
       'Ball Striking - (TOTAL DRV RANK)', 'Driving Accuracy Percentage - (%)',
       'Driving Distance - (AVG.)', 'GIR Percentage from Fairway - (%)',
       'GIR Percentage from Other than Fairway - (%)',
       'Going for the Green - Birdie or Better - (%)',
       'Greens in Regulation Percentage - (%)', 'Putting Average - (AVG)',
       'Putting Average - (BIRDIE CONVERSION)',
       'Putting Average - (GIR PUTTS)', 'Putting Average - (GIR RANK)',
       'Putts Per Round - (AVG)', 'Putts made Distance - (DISTANCE IN INCHES)',
       'Sand Save Percentage - (%)', 
       'Scrambling - (%)',
       'Short Game Rating - (RATING)',
       'Total Money (Official and Unofficial) - (MONEY)', 'Year']

df = df[col].astype(float)

# %%
test = df[df['Year'] == 2018]

# %%
train = df[df['Year'] <= 2017]

# %%
train['Total Money (Official and Unofficial) - (MONEY)'].mean()
# Out:
# 1517764.5663299663

# %%
guess = train['Total Money (Official and Unofficial) - (MONEY)'].mean()
errors = guess - train['Total Money (Official and Unofficial) - (MONEY)']
mean_absolute_error = errors.abs().mean()
print(f'Guessing the average would give me an average error: {mean_absolute_error:,.2f}')
# Out:
# Guessing the average would give me an average error: 1,027,847.72

# %%
from sklearn.model_selection import train_test_split

train, val = train_test_split(train, stratify=train['Year'], random_state=42)

train.shape, val.shape
# Out:
# ((1113, 21), (372, 21))

# %%
target = 'Total Money (Official and Unofficial) - (MONEY)'
X_train = train.drop(columns='Total Money (Official and Unofficial) - (MONEY)')
y_train = train[target]
X_val = val.drop(columns='Total Money (Official and Unofficial) - (MONEY)')
y_val = val[target]
X_test = test.drop(columns='Total Money (Official and Unofficial) - (MONEY)')
y_test = test[target]

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((1113, 20), (372, 20), (193, 20))

# %%
from sklearn.linear_model import LinearRegression
model_linear = LinearRegression()
model_linear.fit(X_train, y_train)
y_pred = model_linear.predict(X_val)
errors = y_pred - y_val
mae = errors.abs().mean()
print(f'Train Error: ${mae:,.0f}')
# Out:
# Train Error: $790,219

# %%
from xgboost import XGBRegressor
model = XGBRegressor(max_depth= 20, random_state=42, n_jobs=-1)

model.fit(X_train, y_train)
# Out:
# [10:48:28] WARNING: /usr/local/miniconda/conda-bld/xgboost_1572315027083/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=20, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
model.score(X_val, y_val)
# Out:
# 0.40197696118020976

# %%
import numpy as np
from scipy.stats import randint, uniform
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

param_distributions = { 
    'n_estimators': randint(50, 500), 
    'max_depth': [5, 10, 15, 20, None], 
    'max_features': uniform(0, 1), 
}

search = RandomizedSearchCV(
    RandomForestRegressor(random_state=42), 
    param_distributions=param_distributions, 
    n_iter=5, 
    cv=2, 
    scoring='neg_mean_absolute_error', 
    verbose=10, 
    return_train_score=True, 
    n_jobs=-1, 
    random_state=42
)

search.fit(X_train, y_train);
# Out:
# Fitting 2 folds for each of 5 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    2.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    3.7s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    3.9s finished

# %%
print('Best hyperparameters', search.best_params_)
print('Cross-validation MAE', -search.best_score_)
model = search.best_estimator_
# Out:
# Best hyperparameters {'max_depth': None, 'max_features': 0.6011150117432088, 'n_estimators': 201}
# Cross-validation MAE 700358.7756106404

# %%
from xgboost import XGBRegressor
model = XGBRegressor(max_depth= 14, random_state=42, n_jobs=-1)

model.fit(X_train, y_train)
# Out:
# [10:48:34] WARNING: /usr/local/miniconda/conda-bld/xgboost_1572315027083/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=14, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_val)
mae = mean_absolute_error(y_val, y_pred)
print(f'Train Error: ${mae:,.0f}')
# Out:
# Train Error: $699,680

# %%
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f'Test Error: ${mae:,.0f}')
# Out:
# Test Error: $810,960

# %%
import shap
row = X_val.iloc[[0]]
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(row)

shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values,
    features=row
)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iZG0S1Y5YJZLJD09WR2XY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 1536909.5, "outValue": 1552022.875, "link": "identity", "featureNames": ["Average Distance of Putts made - (AVG DIST.)", "Average Distance of Putts made - (AVG)", "Ball Striking - (GIR RANK)", "Ball Striking - (TOTAL DRV RANK)", "Driving Accuracy Percentage - (%)", "Driving Distance - (AVG.)", "GIR Percentage from Fairway - (%)", "GIR Percentage from Other than Fairway - (%)", "Going for the Green - Birdie or Better - (%)", "Greens in Regulation Percentage - (%)", "Putting Average - (AVG)", "Putting Average - (BIRDIE CONVERSION)", "Putting Average - (GIR PUTTS)", "Putting Average - (GIR RANK)", "Putts Per Round - (AVG)", "Putts made Distance - (DISTANCE IN INCHES)", "Sand Save Percentage - (%)", "Scrambling - (%)", "Short Game Rating - (RATING)", "Year"], "features": {"0": {"effect": -17089.02734375, "value": 4.6}, "1": {"effect": 9102.5498046875, "value": 80.4}, "2": {"effect": -124620.5703125, "value": 104.0}, "3": {"effect": 78447.1640625, "value": 75.0}, "4": {"effect": -3254.462890625, "value": 65.05}, "5": {"effect": -12986.9853515625, "value": 284.2}, "6": {"effect": -82031.5078125, "value": 73.28}, "7": {"effect": -10285.49609375, "value": 51.28}, "8": {"effect": -28557.994140625, "value": 52.76}, "9": {"effect": -25763.140625, "value": 64.44}, "10": {"effect": -25605.759765625, "value": 1.776}, "11": {"effect": 196842.015625, "value": 30.74}, "12": {"effect": 188567.90625, "value": 1648.0}, "14": {"effect": 18727.876953125, "value": 29.16}, "15": {"effect": -133.8621826171875, "value": 54.0}, "16": {"effect": -41962.71484375, "value": 43.59}, "17": {"effect": -120375.0390625, "value": 57.62}, "18": {"effect": -12299.0576171875, "value": 6.2}, "19": {"effect": 28391.42578125, "value": 2014.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZG0S1Y5YJZLJD09WR2XY')
#   );
# </script>

# %%
import eli5
from eli5.sklearn import PermutationImportance

permuter = PermutationImportance(
    model,
    scoring='neg_mean_absolute_error',
    n_iter=5,
    random_state=42
)

permuter.fit(X_val, y_val)
# Out:
# The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
# The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
# PermutationImportance(cv='prefit',
#                       estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                              colsample_bylevel=1,
#                                              colsample_bynode=1,
#                                              colsample_bytree=1, gamma=0,
#                                              importance_type='gain',
#                                              learning_rate=0.1,
#                                              max_delta_step=0, max_depth=14,
#                                              min_child_weight=1, missing=None,
#                                              n_estimators=100, n_jobs=-1,
#                                              nthread=None,
#                                              objective='reg:linear',
#                                              random_state=42, reg_alpha=0,
#                                              reg_lambda=1, scale_pos_weight=1,
#                                              seed=None, silent=None,
#                                              subsample=1, verbosity=1),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='neg_mean_absolute_error')

# %%
feature_names = X_val.columns.tolist()

eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_names
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 195478.8431
#
#                     &plusmn; 33865.5978
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Putting Average - (BIRDIE CONVERSION)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 64442.8689
#
#                     &plusmn; 32319.6100
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Putting Average - (GIR PUTTS)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 42136.6630
#
#                     &plusmn; 21411.6493
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Ball Striking - (GIR RANK)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 39555.9341
#
#                     &plusmn; 18091.3499
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Scrambling - (%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 36030.5628
#
#                     &plusmn; 28169.6921
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Ball Striking - (TOTAL DRV RANK)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 9939.3459
#
#                     &plusmn; 3653.1082
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Average Distance of Putts made - (AVG)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 9900.3075
#
#                     &plusmn; 10816.7739
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 GIR Percentage from Fairway - (%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 5350.2867
#
#                     &plusmn; 8018.5538
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Putting Average - (AVG)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4719.9095
#
#                     &plusmn; 5326.5091
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Putts Per Round - (AVG)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 3721.5589
#
#                     &plusmn; 6965.7815
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Average Distance of Putts made - (AVG DIST.)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 3357.4557
#
#                     &plusmn; 8931.9736
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Sand Save Percentage - (%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 3348.8645
#
#                     &plusmn; 6903.4964
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Short Game Rating - (RATING)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 2220.7199
#
#                     &plusmn; 11712.4024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Driving Distance - (AVG.)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1233.6391
#
#                     &plusmn; 6118.5149
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Greens in Regulation Percentage - (%)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 956.3078
#
#                     &plusmn; 3148.8767
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 155.0344
#
#                     &plusmn; 198.2542
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Putts made Distance - (DISTANCE IN INCHES)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#                     &plusmn; 0.0000

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 92

# %%
from pdpbox.pdp import pdp_isolate, pdp_plot

feature= 'Putting Average - (BIRDIE CONVERSION)'

isolated = pdp_isolate(
    model=model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

# %%
pdp_plot(isolated, feature_name=feature, plot_lines=False);

# %%
train['Putting Average - (BIRDIE CONVERSION)'].describe()
# Out:
# count    1113.000000
# mean       29.015606
# std         2.290653
# min        21.880000
# 25%        27.460000
# 50%        29.030000
# 75%        30.500000
# max        37.090000
# Name: Putting Average - (BIRDIE CONVERSION), dtype: float64

# %%
feature= 'Driving Distance - (AVG.)'

isolated = pdp_isolate(
    model=model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

# %%
pdp_plot(isolated, feature_name=feature, plot_lines=False);

# %%
train['Driving Distance - (AVG.)'].describe()
# Out:
# count    1113.000000
# mean      290.125786
# std         8.758418
# min       266.400000
# 25%       284.300000
# 50%       289.800000
# 75%       295.600000
# max       318.400000
# Name: Driving Distance - (AVG.), dtype: float64

# %%
feature= 'Driving Accuracy Percentage - (%)'

isolated = pdp_isolate(
    model=model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

# %%
pdp_plot(isolated, feature_name=feature, plot_lines=False);

# %%
train['Driving Accuracy Percentage - (%)'].describe()
# Out:
# count    1113.000000
# mean       61.325013
# std         5.045969
# min        43.020000
# 25%        57.920000
# 50%        61.350000
# 75%        64.790000
# max        76.880000
# Name: Driving Accuracy Percentage - (%), dtype: float64

# %%
from pdpbox.pdp import pdp_interact, pdp_interact_plot

features= ['Putting Average - (BIRDIE CONVERSION)', 'Ball Striking - (GIR RANK)']

interaction = pdp_interact(
    model=model,
    dataset=X_val,
    model_features=X_val.columns,
    features=features
)

# %%
pdp_interact_plot(interaction, plot_type='grid', feature_names=features);

# %%
train['Putting Average - (BIRDIE CONVERSION)']
# Out:
# Name_Year
# David Lynn2013          26.93
# Harris English2012      29.03
# Boo Weekley2016         29.49
# Aron Price2010          29.10
# Roger Sloan2015         29.49
#                         ...
# Darron Stiles2013       26.19
# Ernie Els2016           29.22
# Freddie Jacobson2010    29.12
# Andrew Svoboda2015      28.57
# Chez Reavie2017         29.12
# Name: Putting Average - (BIRDIE CONVERSION), Length: 1113, dtype: float64

# %%
train['Putting Average - (GIR PUTTS)']
# Out:
# Name_Year
# David Lynn2013          1380.0
# Harris English2012      2128.0
# Boo Weekley2016         1810.0
# Aron Price2010          1444.0
# Roger Sloan2015         1058.0
#                          ...
# Darron Stiles2013        983.0
# Ernie Els2016           1279.0
# Freddie Jacobson2010    1789.0
# Andrew Svoboda2015      1587.0
# Chez Reavie2017         1922.0
# Name: Putting Average - (GIR PUTTS), Length: 1113, dtype: float64
