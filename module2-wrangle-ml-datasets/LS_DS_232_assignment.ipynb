# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 1*
#
# ---
#
#
# # Wrangle ML datasets
#
# - [ ] Continue to clean and explore your data.
# - [ ] For the evaluation metric you chose, what score would you get just by guessing?
# - [ ] Can you make a fast, first model that beats guessing?
#
# **We recommend that you use your portfolio project dataset for all assignments this sprint.**
#
# **But if you aren't ready yet, or you want more practice, then use the New York City property sales dataset for today's assignment.** Follow the instructions below, to just keep a subset for the Tribeca neighborhood, and remove outliers or dirty data. [Here's a video walkthrough](https://youtu.be/pPWFw8UtBVg?t=584) you can refer to if you get stuck or want hints!
#
# - Data Source: [NYC OpenData: NYC Citywide Rolling Calendar Sales](https://data.cityofnewyork.us/dataset/NYC-Citywide-Rolling-Calendar-Sales/usep-8jbt)
# - Glossary: [NYC Department of Finance: Rolling Sales Data](https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page)

# %%
# %%capture
# import sys

# # If you're on Colab:
# if 'google.colab' in sys.modules:
#     DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Applied-Modeling/master/data/'
#     !pip install category_encoders==2.*
#     !pip install pandas-profiling==2.*

# # If you're working locally:
# else:
#     DATA_PATH = '../data/'

# %%
# Read New York City property sales data
# import pandas as pd
# df = pd.read_csv(DATA_PATH+'condos/NYC_Citywide_Rolling_Calendar_Sales.csv')

# %%
import pandas as pd

df = pd.read_csv('/Users/robertbuckley/repos/DS-Unit-2-Applied-Modeling/module1-define-ml-problems/driving_stats_2010-2018.csv')

# %% [markdown]
# Your code starts here:

# %%
# Change column names: replace spaces with underscores

# I have NO IDEA how to do this...
df.shape
# Out:
# (1678, 57)

# %%
df.head()
# Out:
#             Name_Year  Driving Accuracy Percentage - (%)  \
# 0  Aaron Baddeley2010                              56.65
# 1  Aaron Baddeley2011                              55.67
# 2  Aaron Baddeley2012                              54.30
# 3  Aaron Baddeley2013                              50.71
# 4  Aaron Baddeley2014                              52.29
#
#   Driving Accuracy Percentage - (FAIRWAYS HIT)  \
# 0                                          741
# 1                                          584
# 2                                          549
# 3                                          465
# 4                                          525
#
#   Driving Accuracy Percentage - (POSSIBLE FAIRWAYS)  \
# 0                                             1,308
# 1                                             1,049
# 2                                             1,011
# 3                                               917
# 4                                             1,004
#
# ...

# %%
df[['Driving Accuracy Percentage - (%)', 'Driving Distance - (AVG.)']]
# Out:
#       Driving Accuracy Percentage - (%)  Driving Distance - (AVG.)
# 0                                 56.65                      298.9
# 1                                 55.67                      296.2
# 2                                 54.30                      292.0
# 3                                 50.71                      288.5
# 4                                 52.29                      293.8
# ...                                 ...                        ...
# 1673                              65.23                      280.1
# 1674                              66.54                      286.8
# 1675                              63.88                      289.8
# 1676                              57.06                      299.5
# 1677                              54.76                      291.9
#
# [1678 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Name_Year', 'Driving Accuracy Percentage - (%)',
#        'Driving Accuracy Percentage - (FAIRWAYS HIT)',
#        'Driving Accuracy Percentage - (POSSIBLE FAIRWAYS)',
#        'Driving Accuracy Percentage - (ROUNDS)', 'Driving Distance - (AVG.)',
#        'Driving Distance - (ROUNDS)', 'Driving Distance - (TOTAL DISTANCE)',
#        'Driving Distance - (TOTAL DRIVES)',
#        'Driving Distance - All Drives - (# OF DRIVES)',
#        'Driving Distance - All Drives - (ALL DRIVES)',
#        'Driving Distance - All Drives - (ROUNDS)',
#        'Driving Distance - All Drives - (TOTAL DISTANCE)',
#        'Driving Pct. 240-260 (All Drives) - (%)',
#        'Driving Pct. 240-260 (All Drives) - (RELATIVE TO PAR)',
#        'Driving Pct. 240-260 (All Drives) - (ROUNDS)',
#        'Driving Pct. 240-260 (All Drives) - (TOTAL DRIVES - OVERALL)',
#        'Driving Pct. 240-260 (All Drives) - (TOTAL DRIVES FOR 240-260)',
#        'Driving Pct. 260-280 (All Drives) - (%)',
# ...

# %%
# column_list = df.columns.tolist()
# column_list.replace(' ', '_')

# %%
# Get Pandas Profiling Report
from pandas_profiling import ProfileReport

profile = ProfileReport(df, title='Pandas Profiling Report', html={'style':{'full_width':True}})

# %%
profile.to_widgets()
# Out:
# ...
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
#'Driving Accuracy Percentage - (ROUNDS)','Driving Distance - (ROUNDS)',
# 'Driving_Accuracy_Percentage_-_(FAIRWAYS_HIT)',
# 'Driving Distance - (AVG.)',  'Driving Distance - All Drives - (# OF DRIVES)',
#        'Driving Distance - All Drives - (ALL DRIVES)',
#        'Driving Distance - All Drives - (ROUNDS)',
#        'Driving Distance - All Drives - (TOTAL DISTANCE)',

# %%
# df.columns
df[['Name_Year', 'Driving_Distance_-_(AVG.)',
       'Driving_Distance_-_(ROUNDS)',
       'Driving_Distance_-_(TOTAL_DISTANCE)',
       'Driving_Distance_-_(TOTAL_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(#_OF_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(ALL_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(ROUNDS)',
       'Driving_Distance_-_All_Drives_-_(TOTAL_DISTANCE)',
       'Driving_Pct._240-260_(All_Drives)_-_(%)',
       'Driving_Pct._240-260_(All_Drives)_-_(RELATIVE_TO_PAR)',
       'Driving_Pct._240-260_(All_Drives)_-_(ROUNDS)',
       'Driving_Pct._240-260_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
       'Driving_Pct._240-260_(All_Drives)_-_(TOTAL_DRIVES_FOR_240-260)'
  ]]
# Out:
#                Name_Year  Driving_Distance_-_(AVG.)  \
# 0     Aaron Baddeley2010                      298.9
# 1     Aaron Baddeley2011                      296.2
# 2     Aaron Baddeley2012                      292.0
# 3     Aaron Baddeley2013                      288.5
# 4     Aaron Baddeley2014                      293.8
# ...                  ...                        ...
# 1673    Zach Johnson2016                      280.1
# 1674    Zach Johnson2017                      286.8
# 1675    Zach Johnson2018                      289.8
# 1676     Zack Miller2011                      299.5
# 1677     Zecheng Dou2018                      291.9
#
#       Driving_Distance_-_(ROUNDS) Driving_Distance_-_(TOTAL_DISTANCE)  \
# 0                              94                              56,202
# 1                              77                              44,430
# 2                              73                              42,048
# ...

# %%
#Checking to see if 'Driving_Distance_' stats are only taking at max two drives per round of golf played

df['drives_rounds_ratio'] = df['Driving_Distance_-_(TOTAL_DRIVES)'] / df['Driving_Distance_-_(ROUNDS)']

(df['drives_rounds_ratio'] > 2).value_counts()

#confirms that these stats take just the best from the front 9 and the best from the back 9 of each
#round of golf played to calculate this stat.
#So at max there will be two per round, but less than two when a set of 9 holes didn't have a drive or a drive 
#that was in the fairway
#Now I know I only need to keep the % column
# Out:
# False    1678
# Name: drives_rounds_ratio, dtype: int64

# %%
df[['Name_Year', 'Driving_Accuracy_Percentage_-_(%)',
       'Driving_Accuracy_Percentage_-_(FAIRWAYS_HIT)',
       'Driving_Accuracy_Percentage_-_(POSSIBLE_FAIRWAYS)',
       'Driving_Accuracy_Percentage_-_(ROUNDS)', 'Driving_Distance_-_(AVG.)',
       'Driving_Distance_-_(ROUNDS)', 'Driving_Distance_-_(TOTAL_DISTANCE)',
       'Driving_Distance_-_(TOTAL_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(#_OF_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(ALL_DRIVES)',
       'Driving_Distance_-_All_Drives_-_(ROUNDS)',
       'Driving_Distance_-_All_Drives_-_(TOTAL_DISTANCE)']]
# Out:
#                Name_Year  Driving_Accuracy_Percentage_-_(%)  \
# 0     Aaron Baddeley2010                              56.65
# 1     Aaron Baddeley2011                              55.67
# 2     Aaron Baddeley2012                              54.30
# 3     Aaron Baddeley2013                              50.71
# 4     Aaron Baddeley2014                              52.29
# ...                  ...                                ...
# 1673    Zach Johnson2016                              65.23
# 1674    Zach Johnson2017                              66.54
# 1675    Zach Johnson2018                              63.88
# 1676     Zack Miller2011                              57.06
# 1677     Zecheng Dou2018                              54.76
#
#      Driving_Accuracy_Percentage_-_(FAIRWAYS_HIT)  \
# 0                                             741
# 1                                             584
# 2                                             549
# ...

# %%
df.shape
# Out:
# (1678, 58)

# %%
df = df[df.columns.drop(list(df.filter(regex='ROUNDS')))]
df.shape
# Out:
# (1678, 47)

# %%
list_to_drop = ['Driving_Accuracy_Percentage_-_(FAIRWAYS_HIT)',
               'Driving_Accuracy_Percentage_-_(POSSIBLE_FAIRWAYS)']
list_to_drop
# Out:
# ['Driving_Accuracy_Percentage_-_(FAIRWAYS_HIT)',
#  'Driving_Accuracy_Percentage_-_(POSSIBLE_FAIRWAYS)']

# %%
df = df[df.columns.drop(list_to_drop)]

# %%
df.shape
# Out:
# (1678, 45)

# %%
df.columns.str.contains('Driving')
# Out:
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True,  True,  True,  True, False])

# %%
df.filter(regex='TOTAL').columns
# Out:
# Index(['Driving_Distance_-_(TOTAL_DISTANCE)',
#        'Driving_Distance_-_(TOTAL_DRIVES)',
#        'Driving_Distance_-_All_Drives_-_(TOTAL_DISTANCE)',
#        'Driving_Pct._240-260_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
#        'Driving_Pct._240-260_(All_Drives)_-_(TOTAL_DRIVES_FOR_240-260)',
#        'Driving_Pct._260-280_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
#        'Driving_Pct._260-280_(All_Drives)_-_(TOTAL_DRIVES_FOR_260-280)',
#        'Driving_Pct._280-300_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
#        'Driving_Pct._280-300_(All_Drives)_-_(TOTAL_DRIVES_FOR_280-300)',
#        'Driving_Pct._300+_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
#        'Driving_Pct._300+_(All_Drives)_-_(TOTAL_DRIVES_FOR_300+)',
#        'Driving_Pct._<=_240_(All_Drives)_-_(TOTAL_DRIVES_-_OVERALL)',
#        'Driving_Pct._<=_240_(All_Drives)_-_(TOTAL_DRIVES_FOR_<=_240)',
#        'Left_Rough_Tendency_-_(TOTAL_LEFT_ROUGH)',
#        'Missed_Fairway_Percent_-_Other_-_(TOTAL_FWYS)',
# ...

# %%
df['Year'] = df.Name_Year.str[-4:]

# %%
df['Name_Year'] = df.Name_Year.str[:-4]

# %%
df = df.rename(columns={'Name_Year': 'Player_Name'})

# %%
df
# Out:
#          Player_Name  Driving_Accuracy_Percentage_-_(%)  \
# 0     Aaron Baddeley                              56.65
# 1     Aaron Baddeley                              55.67
# 2     Aaron Baddeley                              54.30
# 3     Aaron Baddeley                              50.71
# 4     Aaron Baddeley                              52.29
# ...              ...                                ...
# 1673    Zach Johnson                              65.23
# 1674    Zach Johnson                              66.54
# 1675    Zach Johnson                              63.88
# 1676     Zack Miller                              57.06
# 1677     Zecheng Dou                              54.76
#
#       Driving_Distance_-_(AVG.) Driving_Distance_-_(TOTAL_DISTANCE)  \
# 0                         298.9                              56,202
# 1                         296.2                              44,430
# 2                         292.0                              42,048
# ...

# %%
df.to_csv('driving_stats_2010-2018_cleaned.csv')

# %%
# Keep just the subset of data for the Tribeca neighborhood
# Check how many rows you have now. (Should go down from > 20k rows to 146)

# %%
# Q. What's the date range of these property sales in Tribeca?

# %%
# The Pandas Profiling Report showed that SALE_PRICE was read as strings
# Convert it to integers

# %%
# Q. What is the maximum SALE_PRICE in this dataset?

# %%
# Look at the row with the max SALE_PRICE

# %%
# Get value counts of TOTAL_UNITS
# Q. How many property sales were for multiple units?

# %%
# Keep only the single units

# %%
# Q. Now what is the max sales price? How many square feet does it have?

# %%
# Q. How often did $0 sales occur in this subset of the data?

# There's a glossary here: 
# https://www1.nyc.gov/site/finance/taxes/property-rolling-sales-data.page

# It says:
# A $0 sale indicates that there was a transfer of ownership without a 
# cash consideration. There can be a number of reasons for a $0 sale including 
# transfers of ownership from parents to children.

# %%
# Look at property sales for > 5,000 square feet
# Q. What is the highest square footage you see?

# %%
# What are the building class categories?
# How frequently does each occur?

# %%
# Keep subset of rows:
# Sale price more than $0, 
# Building class category = Condos - Elevator Apartments

# Check how many rows you have now. (Should be 106 rows.)

# %%
# Make a Plotly Express scatter plot of GROSS_SQUARE_FEET vs SALE_PRICE

# %%
# Add an OLS (Ordinary Least Squares) trendline,
# to see how the outliers influence the "line of best fit"

# %%
# Look at sales for more than $35 million

# All are at 70 Vestry Street
# All but one have the same SALE_PRICE & SALE_DATE
# Was the SALE_PRICE for each? Or in total?
# Is this dirty data?

# %%
# Make a judgment call:
# Keep rows where sale price was < $35 million

# Check how many rows you have now. (Should be down to 90 rows.)

# %%
# Now that you've removed outliers,
# Look again at a scatter plot with OLS (Ordinary Least Squares) trendline

# %%
# Select these columns, then write to a csv file named tribeca.csv. Don't include the index.
